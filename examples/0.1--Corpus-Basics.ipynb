# %%
import pandas as pd
import seaborn as sns

import cltrier_nlp as nlp

# %%
corpus = nlp.corpus.Corpus.from_txt('./data/corpus.txt')
corpus.to_df()
# Out:
#                                                content language  \
# 0    "datenschutz ist nicht nur ein recht, es ist e...   german
# 1    💻🚫👀 why do companies and governments still not...  english
# 2    our personal information is not their playground!  english
# 3    🤯 #dataprivacy #protectourdata #privacymatters...  english
# 4    🤔 gibt esgrenzen für die verwendung unserer da...   german
# ..                                                 ...      ...
# 614  "wir sollten unsere persönlichen informationen...   german
# 615             💻❓️ datenschutz ist ein menschenrecht!   german
# 616  🌎👀 #datenschutz #privatsphäre #security"  tran...  english
# 617                 💻❓️ data privacy is a human right!  english
# 618                🌎👀 #dataprivacy #privacy #security"  english
#
#                                                 tokens  \
# 0    [``, datenschutz, ist, nicht, nur, ein, recht,...
# 1    [💻🚫👀, why, do, companies, and, governments, st...
# ...

# %%
(
    pd.DataFrame(
        corpus
        .count_languages()
        .most_common(20),
    )
    .rename(columns={
        0: 'lang',
        1: 'count'
    })
)
# Out:
#         lang  count
# 0     german    449
# 1    english    132
# 2    swedish     14
# 3      dutch      8
# 4  afrikaans      7
# 5    italian      5
# 6    catalan      1
# 7     french      1
# 8   estonian      1
# 9    swahili      1

# %%
sns.barplot(
    pd.DataFrame(
        corpus
        .count_tokens()
        .most_common(20),
    )
    .rename(columns={
        0: 'token',
        1: 'count'
    }),
    x='count',
    y='token',
    hue='token'
)
# Out:
# <Axes: xlabel='count', ylabel='token'>
# /Users/simon/Library/Caches/pypoetry/virtualenvs/cltrier-nlp-4sfjUWJz-py3.11/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 129300 (\N{THINKING FACE}) missing from current font.
#   func(*args, **kwargs)
# /Users/simon/Library/Caches/pypoetry/virtualenvs/cltrier-nlp-4sfjUWJz-py3.11/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 129300 (\N{THINKING FACE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
(
    pd.DataFrame(
        corpus
        .count_ngrams(4)
        .most_common(40),
    )
    .rename(columns={
        0: 'token',
        1: 'count'
    })
)
# Out:
#                                               token  count
# 0                 (#, datenschutz, #, privatsphäre)    169
# 1                 (datenschutz, #, privatsphäre, #)    149
# 2                        ('', ``, datenschutz, ist)     62
# 3                  (#, privatsphäre, #, sicherheit)     62
# 4                 (privatsphäre, #, sicherheit, '')     58
# 5                           (#, sicherheit, '', ``)     58
# 6                            (ist, nicht, nur, ein)     38
# 7                          (nicht, nur, ein, recht)     38
# 8                              (nur, ein, recht, ,)     38
# 9                    (datenschutz, ist, nicht, nur)     36
# 10                    (``, datenschutz, ist, nicht)     35
# 11                              (ein, recht, ,, es)     34
# 12                              (recht, ,, es, ist)     34
# 13                               (,, es, ist, eine)     34
# 14                         (es, ist, eine, pflicht)     33
# ...
